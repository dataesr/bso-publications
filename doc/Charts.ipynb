# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import math

# %%
SIZE = 22
SMALL_SIZE=18
plt.rc('font', size=SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SIZE)    # legend fontsize
plt.rc('figure', titlesize=SIZE)  # fontsize of the figure title

with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Munroe
    # https://xkcd.com/418/
    
    fig, axs = plt.subplots(1, 3, figsize=(20,8), dpi=100)
    
    
    for ax in axs:
        #ax.set(xlabel='x-label', ylabel='y-label')
        #ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
        
        ax.spines.right.set_color('none')
        ax.spines.top.set_color('none')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylim([0.2, 0.7])
        ax.set_xlabel('publication year')
        ax.set_ylabel('Open Access rate (%)')


    data_flat = [0.4, 0.39, 0.41, 0.41, 0.4]
    data_increase = [0.3, 0.35, 0.4, 0.45, 0.55]
    data_inverted = [0.3, 0.35, 0.4, 0.45, 0.35]


    #ax.plot(data_flat)
    #ax.plot(data_increase)
    axs[0].plot(data_increase)
    axs[0].set_title('Increasing curve')
    
    for i in [1,2,3]:
        axs[0].annotate(
            'Open Access rates\nall measured at the\nsame time (with a\nsnapshot of the\nUnpaywall database)',
            xy=(i, data_increase[i]), arrowprops=dict(arrowstyle='->'), xytext=(1, 0.5), fontsize=SMALL_SIZE)
    

    
    axs[1].plot(data_flat)
    axs[1].set_title('Flat curve')
    
    axs[2].plot(data_inverted)
    axs[2].set_title('Inverted-V curve')
    
    axs[2].annotate(
            'The most recent publications\nare not the most open\nin the inverted-V curve case',
            xy=(4, data_inverted[4]), arrowprops=dict(arrowstyle='->'), xytext=(1, 0.6), fontsize=SMALL_SIZE)
    
    fig.savefig('types_curve.png')

# %%
with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Munroe
    # https://xkcd.com/418/

    fig = plt.figure(figsize=(15,8), dpi=100)

    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.spines.right.set_color('none')
    ax.spines.top.set_color('none')

    ax.set_yticks([])
    ax.set_ylim([0.2, 0.7])

    data1 = [0.3, 0.35, 0.40, 0.32]
    data2 = [0.43, 0.43, 0.45, 0.46, 0.43]
    data3 = [0.45, 0.48, 0.5, 0.53, 0.55, 0.6]


    # Set number of ticks for x-axis
    ax.set_xticks(range(0, len(data3)))
    # Set ticks labels for x-axis
    ax.set_xticklabels(['Y-6', 'Y-5', 'Y-4', 'Y-3', 'Y-2', 'Y-1']
                        , rotation='vertical', fontsize=SMALL_SIZE)

    ax.plot(data1, label='Observed in Y-2')
    ax.plot(data2, label='Observed in Y-1')
    ax.plot(data3, label='Observed in Y')
    
    ax.legend()

    ax.annotate(
            'Last publication\nyear Y-1 is observed in year Y',
            xy=(5, data3[5]), arrowprops=dict(arrowstyle='->'), xytext=(4, 0.47), fontsize=SMALL_SIZE)

    ax.set_xlabel('publication year')
    ax.set_ylabel('Open Access rate (%)')
    
    ax.set_title('Open access curve shape dynamics')
    
    fig.savefig('curve_dynamic.png')

# %%
with plt.xkcd():

    
    fig, axs = plt.subplots(1, 2, figsize=(20,8), dpi=100)
    
    
    width = 0.25

    oa1 = [0.15, 0.16, 0.17, 0.17]
    oa2 = [0.13, 0.14, 0.17, 0.12]
    oa3 = [0.2, 0.2, 0.25, 0.25]

    labels = ['Y-4', 'Y-3', 'Y-2', 'Y-1']
    
    axs[0].bar(labels, oa1, width, label='Green in Unpaywall', color='#19905b')
    axs[0].bar(labels, [oa2[k] + oa3[k] for k in range(0, len(oa2))], width,
               label='Gold or Hybrid or Bronze\nin Unpaywall', bottom=oa1, color='#e3bd41')
    
    axs[1].bar(labels, oa1, width, label='hosted only on an open repository', color='#19905B')
    axs[1].bar(labels, oa3, width,
               label='hosted on an open repository\nand by the publisher', bottom=oa1, color='#91AE4F')
    axs[1].bar(labels, oa2, width,
               label='hosted only by the publisher', 
               bottom=[oa1[k] + oa3[k] for k in range(0, len(oa1))], color='#E9D737')
    
    


    # Set number of ticks for x-axis
    ax.set_xticks(range(0, len(oa1)))
    # Set ticks labels for x-axis
    ax.set_xticklabels(labels, rotation='vertical', fontsize=SMALL_SIZE)


    for ax in axs:
        ax.spines.right.set_color('none')
        ax.spines.top.set_color('none')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_ylim([0, 1])
        ax.set_xlabel('publication year')
        ax.set_ylabel('Open Access rate (%)')
        ax.legend()

    
    axs[0].set_title('Open Access types using\nUnpaywall OA status')
    axs[1].set_title('Open Access types in the\nFrench Open Science Monitor')
    
    fig.savefig('oa_types.png')

# %%
with plt.xkcd():
    # Based on "Stove Ownership" from XKCD by Randall Munroe
    # https://xkcd.com/418/

    fig = plt.figure(figsize=(15,8), dpi=100)

    ax = fig.add_axes((0.1, 0.2, 0.8, 0.7))
    ax.spines.right.set_color('none')
    ax.spines.top.set_color('none')

    ax.set_yticks([])
    ax.set_ylim([0, 1.1])
    ax.set_xticks([])
    ax.set_xlim([0, 1.1])

    x_data = [0.2, 0.5, 0.8, 0.1]
    y_data = [0.7,0.7,0.2, 0.2]
    s_data = [1*1000, 5*1000, 8*1000, 3*1000]

    ax.scatter(x=x_data, y=y_data, s=s_data)
    ax.scatter(x=[1], y=[1], marker='*', s=[2000], color='#e1e1e1')
    ax.plot([0, 1], color = '#e1e1e1', linestyle = 'dashed')
    

    ax.set_xlabel('Share of publications in open access\nwith a copy hosted by the publisher')
    ax.set_ylabel('Share of publications in open access\nwith a copy hosted in a repository')
    
    # Set number of ticks for x-axis
    ax.set_xticks(range(0, 2))
    ax.set_yticks(range(0, 2))
    # Set ticks labels for x-axis
    ax.set_xticklabels(['0%', '100%'], rotation='vertical', fontsize=SMALL_SIZE)
    ax.set_yticklabels(['0%', '100%'], rotation='vertical', fontsize=SMALL_SIZE)
    
    ax.annotate(
            'Target for\nOpen Science in France',
            xy=(1, 1), arrowprops=dict(arrowstyle='->'), xytext=(0.8, 0.6), fontsize=SMALL_SIZE)
    
    for i in range(0, len(x_data)):
        ax.annotate(f'Publications cluster {i+1}', xy=(x_data[i], y_data[i]), 
                   xytext=(x_data[i]-0.07, y_data[i]+0.1)
                   )
    
    #ax.set_title('Open repositories and publisher hosting share')
    
    fig.savefig('bubbles.png')

# %%
from matplotlib.patches import Rectangle, Circle, Ellipse
colors = plt.cm.Dark2.colors + plt.cm.Accent.colors

fig_width = 20
fig_height = 13

top = fig_height - 0.5

bg_color = 'white'
color="#1e1e1e"
with plt.xkcd():
    fig = plt.figure(figsize=(fig_width, fig_height), dpi=100)
    ax = fig.add_axes((0, 0, 1, 1))
    ax.set_xlim(0, fig_width)
    ax.set_ylim(0, fig_height)
    ax.set_facecolor(bg_color)

    ax.tick_params(bottom=False, top=False,
                   left=False, right=False)
    ax.tick_params(labelbottom=False, labeltop=False,
                   labelleft=False, labelright=False)

    ax.spines["top"].set_color(color)
    ax.spines["bottom"].set_color(color)
    ax.spines["left"].set_color(color)
    ax.spines["right"].set_color(color)
    ax.spines["top"].set_linewidth(4)
    ax.spines["bottom"].set_linewidth(4)
    ax.spines["left"].set_linewidth(4)
    ax.spines["right"].set_linewidth(4)
    
    # colonne 1
    ax.annotate('Metadata sources', xy=(2, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate('Affiliations metadata', xy=(2, top-0.7), color='#1E1E1E', weight='bold', fontsize=22, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-2), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('PubMed', xy=(2, top-2+0.4), color='#1E1E1E', weight='bold', fontsize=25, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-3.5), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Crawling', xy=(2, top-3.5+0.4), color='#1E1E1E', weight='bold', fontsize=25, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-5), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('CrossRef\n(via Unpaywall)', xy=(2, top-5+0.2), color='#1E1E1E', weight='bold', fontsize=21, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-6.5), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Legacy DOI list', xy=(2, top-6.5+0.4), color='#1E1E1E', weight='bold', fontsize=23, ha='center')
    
    ax.annotate('Other metadata', xy=(1.7, top-7.5), color='#1E1E1E', weight='bold', fontsize=22, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-9), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Unpaywall\nsnapshots', xy=(2, top-9+0.2), color='#1E1E1E', weight='bold', fontsize=23, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-10.5), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('OpenAPC', xy=(2, top-10.5+0.4), color='#1E1E1E', weight='bold', fontsize=23, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-12), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('DOAJ', xy=(2, top-12+0.4), color='#1E1E1E', weight='bold', fontsize=23, ha='center')
    
    # 2e colonne
    ax.annotate('Enrichments & filter', xy=(10.5, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(4.5,top-1.5),(3.5,top-1.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((5.5, top-1.5), 2, 1.2, edgecolor=colors[0], facecolor='w', linewidth=2))
    ax.annotate('PubMed XML\nparser', xy=(5.5, top-1.8), color=colors[0], weight='bold', fontsize=20, ha='center')
    
    ax.annotate("",(4.5,top-3),(3.5,top-3),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((5.5, top-3), 2, 1.2, edgecolor=colors[1], facecolor='w', linewidth=2))
    ax.annotate('HTML\nparser', xy=(5.5, top-3.3), color=colors[1], weight='bold', fontsize=20, ha='center')
    
    # 3e colonne
    ax.annotate("",(7.5,top-3),(6.5,top-3),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(7.5,top-3),(6.5,top-1.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(7.5,top-3.1),(3.5,top-4.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((8.5, top-3), 2, 1.2, edgecolor=colors[2], facecolor='w', linewidth=2))
    ax.annotate('Affiliation\nmatcher', xy=(8.5, top-3.2), color=colors[2], weight='bold', fontsize=20, ha='center')
    
    # 4e colonne
    ax.annotate("",(10.5,top-4.5),(9.5,top-3),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(10.5,top-4.6),(3.5,top-6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Rectangle((10.5, top-5), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate("'French'\npublications", xy=(11.5, top-4.7), color='#1E1E1E', weight='bold', fontsize=20, ha='center')
    
    #5e colonne
    ax.annotate("",(14,top-6),(3.5,top-8.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(14,top-6.1),(3.5,top-10),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(14,top-6.2),(3.5,top-11.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(14,top-5.9),(12.5,top-4.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(15,top-5.3),(15,top-3.6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((15, top-6), 2, 1.5, edgecolor=colors[3], facecolor='w', linewidth=2))
    ax.annotate('Enrichments', xy=(15, top-6), color=colors[3], weight='bold', fontsize=20, ha='center')
    
    
    ax.add_patch(Ellipse((15, top-3), 2, 1.2, edgecolor=colors[4], facecolor='w', linewidth=2))
    ax.annotate('Scientific\ntagger', xy=(15, top-3.3), color=colors[4], weight='bold', fontsize=20, ha='center')
    
    
    #6e colonne
    ax.annotate('Exposition', xy=(18.5, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(17.5,top-7.5+2),(16,top-6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-10+2),(18.5,top-8+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-5+2),(18.5,top-7+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Rectangle((17.5, top-5+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Open Data\ndump', xy=(18.5, top-5+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')
    
    ax.add_patch(Rectangle((17.5, top-8+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Elasticsearch\n (open API)', xy=(18.5, top-8+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')

    ax.add_patch(Ellipse((18.5, top-11+2.3), 2, 1.5, edgecolor=colors[5], facecolor='w', linewidth=2))
    ax.annotate('Web UI\nFrench OSM', xy=(18.5, top-11+0.2+2), color=colors[5], weight='bold', fontsize=20, ha='center')
    
    ax.annotate('Open source code', xy=(15, 2.3), weight='bold', fontsize=20)
    ax.annotate('https://github.com/dataesr/harvest-pubmed', xy=(15, 2.3-0.4), fontsize=15, color=colors[0])
    ax.annotate('https://github.com/dataesr/bso-parser-html', xy=(15, 2.3-0.4 - 0.3), fontsize=15, color=colors[1])
    ax.annotate('https://github.com/dataesr/matcher', xy=(15, 2.3-0.4 - 0.3*2), fontsize=15, color=colors[2])
    ax.annotate('https://github.com/dataesr/bso-publications', xy=(15, 2.3-0.4 - 0.3*3), fontsize=15, color=colors[3])
    ax.annotate('https://github.com/dataesr/scientific_tagger', xy=(15, 2.3-0.4 - 0.3*4), fontsize=15, color=colors[4])
    ax.annotate('https://github.com/dataesr/bso-ui', xy=(15, 2.3-0.4 - 0.3*5), fontsize=15, color=colors[5])
    
    fig.savefig('flow_chart_publications.png')

# %%
from matplotlib.patches import Rectangle, Circle, Ellipse

fig_width = 20
fig_height = 13

top = fig_height - 0.5

bg_color = 'white'
color="#1e1e1e"
with plt.xkcd():
    fig = plt.figure(figsize=(fig_width, fig_height), dpi=100)
    ax = fig.add_axes((0, 0, 1, 1))
    ax.set_xlim(0, fig_width)
    ax.set_ylim(0, fig_height)
    ax.set_facecolor(bg_color)

    ax.tick_params(bottom=False, top=False,
                   left=False, right=False)
    ax.tick_params(labelbottom=False, labeltop=False,
                   labelleft=False, labelright=False)

    ax.spines["top"].set_color(color)
    ax.spines["bottom"].set_color(color)
    ax.spines["left"].set_color(color)
    ax.spines["right"].set_color(color)
    ax.spines["top"].set_linewidth(4)
    ax.spines["bottom"].set_linewidth(4)
    ax.spines["left"].set_linewidth(4)
    ax.spines["right"].set_linewidth(4)
    
    # colonne 1
    ax.annotate('Metadata sources', xy=(2, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate('Registries metadata', xy=(2, top-0.7), color='#1E1E1E', weight='bold', fontsize=22, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-2), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('clinicaltrials.org\nAPI', xy=(2, top-2+0.2), color='#1E1E1E', weight='bold', fontsize=25, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-4), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('EUCTR crawling', xy=(2, top-4+0.4), color='#1E1E1E', weight='bold', fontsize=25, ha='center')
    
    ax.annotate('Other metadata', xy=(1.7, top-5.5), color='#1E1E1E', weight='bold', fontsize=22, ha='center')
    
    ax.add_patch(Rectangle((0.5, top-7), 3, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Unpaywall\nsnapshots', xy=(2, top-7+0.2), color='#1E1E1E', weight='bold', fontsize=23, ha='center')
    
    # 2e colonne
    ax.annotate('Enrichments & filter', xy=(10.5, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(4.5,top-1.5),(3.5,top-1.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((6.2, top-1.5), 3.5, 1.5, edgecolor=colors[8], facecolor='w', linewidth=2))
    ax.annotate('CT json parser &\nFrench locations filter', xy=(6.2, top-1.8), color=colors[8], weight='bold', fontsize=20, ha='center')
    
    ax.annotate("",(4.5,top-3.5),(3.5,top-3.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((6.2, top-3.5), 3.5, 1.5, edgecolor=colors[8], facecolor='w', linewidth=2))
    ax.annotate('EUCTR HTML parser &\nFrench locations filter', xy=(6.2, top-3.8), color=colors[8], weight='bold', fontsize=20, ha='center')
    
    # 3e colonne
    ax.annotate("",(9,top-3),(8,top-3.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(9,top-3),(8,top-1.5),arrowprops=dict(arrowstyle = "-|>", lw=3))

    ax.add_patch(Ellipse((10, top-3), 2, 1.2, edgecolor=colors[8], facecolor='w', linewidth=2))
    ax.annotate('Reconciliation\nNCTId, eudraCT', xy=(10, top-3.2), color=colors[8], weight='bold', fontsize=17, ha='center')
    
    
    #5e colonne
    ax.annotate("",(14,top-6.1),(3.5,top-6.5),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(14,top-6),(11,top-3),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((15, top-6), 2, 1.5, edgecolor=colors[8], facecolor='w', linewidth=2))
    ax.annotate('Enrichments', xy=(15, top-6), color=colors[8], weight='bold', fontsize=20, ha='center')
    
    
    #6e colonne
    ax.annotate('Exposition', xy=(18.5, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(17.5,top-7.5+2),(16,top-6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-10+2),(18.5,top-8+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-5+2),(18.5,top-7+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Rectangle((17.5, top-5+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Open Data\ndump', xy=(18.5, top-5+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')
    
    ax.add_patch(Rectangle((17.5, top-8+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Elasticsearch\n (open API)', xy=(18.5, top-8+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')
    
    ax.add_patch(Ellipse((18.5, top-11+2.3), 2, 1.5, edgecolor=colors[5], facecolor='w', linewidth=2))
    ax.annotate('Web UI\nFrench OSM', xy=(18.5, top-11+0.2+2), color=colors[5], weight='bold', fontsize=20, ha='center')
    
    ax.annotate('Open source code', xy=(15, 2.3), weight='bold', fontsize=20)
    
    ax.annotate('https://github.com/dataesr/bso-clinical-trials', xy=(15, 2.3-0.4 - 0.3), fontsize=15, color=colors[8])
    ax.annotate('https://github.com/dataesr/bso-ui', xy=(15, 2.3-0.4 - 0.3*2), fontsize=15, color=colors[5])
    
    
    fig.savefig('flow_chart_registries.png')
